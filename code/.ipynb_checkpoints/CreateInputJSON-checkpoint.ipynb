# %%
import os, sys
import glob
import json
import subprocess

import pandas as pd

# %% [markdown]
# ## Create example stimuli to source
#
# Below we go through each .mp4 file at the path ```stim_dir``` and use [ffmpeg (a video processing tool](https://www.ffmpeg.org/) to cut 15 seconds of the video (starting at minute 2 and going 15 seconds forward).

# %%
stim_dir = '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders'
out_dir = '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli'

# get all mp4 files in the directory
stim_list = sorted(glob.glob(os.path.join(stim_dir, '*.mp4')))

if not os.path.exists(out_dir):
    os.makedirs(out_dir)

for stim_fn in stim_list:

    out_fn = os.path.basename(stim_fn).replace('.mp4', '_cut.mp4')
    out_fn = os.path.join(out_dir, out_fn)

    subprocess.run(f'ffmpeg -y -i {stim_fn} -ss 0:02:00 -t 0:00:15 -c copy {out_fn}', shell=True)
# Out:
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders01.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:12:18.92, start: 0.000000, bitrate: 2094 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 1961 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders01_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 1961 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  204 fps=0.0 q=-1.0 Lsize=    1687kB time=00:00:14.99 bitrate= 921.7kbits/s speed= 429x
# video:1444kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.497569%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders02.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:09:43.60, start: 0.000000, bitrate: 1467 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 1333 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders02_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 1333 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  291 fps=0.0 q=-1.0 Lsize=    1888kB time=00:00:14.99 bitrate=1031.3kbits/s speed= 258x
# video:1643kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.547295%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders03.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:10:18.20, start: 0.000000, bitrate: 1537 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 1404 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders03_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 1404 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  315 fps=0.0 q=-1.0 Lsize=    2554kB time=00:00:14.99 bitrate=1394.8kbits/s speed=94.2x
# video:2309kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.395111%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders04.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:12:27.24, start: 0.000000, bitrate: 2272 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 2138 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders04_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 2138 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  280 fps=0.0 q=-1.0 Lsize=    2455kB time=00:00:14.99 bitrate=1341.0kbits/s speed=84.4x
# video:2211kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.399987%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders05.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:11:22.68, start: 0.000000, bitrate: 2282 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 2148 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders05_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 2148 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  342 fps=0.0 q=-1.0 Lsize=    2425kB time=00:00:14.99 bitrate=1324.8kbits/s speed= 132x
# video:2180kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.438681%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders06.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:11:23.00, start: 0.000000, bitrate: 1530 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 1396 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders06_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 1396 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  186 fps=0.0 q=-1.0 Lsize=    1683kB time=00:00:14.99 bitrate= 919.2kbits/s speed=88.5x
# video:1440kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.468229%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders07.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:11:29.60, start: 0.000000, bitrate: 2065 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 1931 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders07_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 1931 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  348 fps=0.0 q=-1.0 Lsize=    2415kB time=00:00:14.99 bitrate=1318.9kbits/s speed= 105x
# video:2168kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.484060%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders08.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:11:36.64, start: 0.000000, bitrate: 2389 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 2255 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders08_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 2255 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  338 fps=0.0 q=-1.0 Lsize=    6297kB time=00:00:14.99 bitrate=3439.5kbits/s speed=54.1x
# video:6051kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.170378%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/raiders09.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.3.100
#   Duration: 00:09:12.64, start: 0.000000, bitrate: 1968 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 2742:1931 DAR 233984:102343], 1834 kb/s, SAR 13568:9555 DAR 65536:28665, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to '/dartfs/rc/lab/F/FinnLab/dallas/online-experiments/continuous-rater/stimuli/raiders09_cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1024x636 [SAR 13568:9555 DAR 65536:28665], q=2-31, 1834 kb/s, 25 fps, 25 tbr, 12800 tbn, 12800 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.3.100 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  134 fps=0.0 q=-1.0 Lsize=    1452kB time=00:00:14.99 bitrate= 793.1kbits/s speed=86.8x
# video:1211kB audio:235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.471315%
# ffmpeg version 4.4.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (conda-forge gcc 10.3.0-16)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/x86_64-conda-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-demuxer=dash --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-vaapi --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-libvpx --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1653050584957/_build_env/bin/pkg-config
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# /dartfs/rc/lab/F/FinnLab/datasets/IBC/stimuli/raiders/whisperx: Is a directory

# %% [markdown]
# ## Create JSPsych inputs (participant parameter files)
#
# It is easier to customize randomization outside of JSPsych (e.g., for counterbalancing stimuli across participants). Therefore, we start by creating a set of files (one for each participant) that specifies the order in which participants should view the stimuli.
#
# We will load this file through javascript and use the parameters specified in the file to setup the experiment [through timeline variables](https://www.jspsych.org/v7/overview/timeline/#timeline-variables).

# %%
# make 10 subjects worth of files
N_SUBS = 10
TASK = 'continuous-rater'

base_dir = '/dartfs/rc/lab/F/FinnLab/dallas/continuous-rater/'
stim_dir = os.path.join(base_dir, 'stimuli')
orders_dir = os.path.join(base_dir, 'presentation-orders')

# make the directory to write out json files
if not os.path.exists(orders_dir):
    os.makedirs(orders_dir)

# find all mp4 files in the path stim dir
stim_list = glob.glob(os.path.join(stim_dir, '*.mp4'))
stim_list = stim_list[:2] # only use 2 stimuli for the moment

# create a dataframe to hold experiment information
df = pd.DataFrame(stim_list, columns=['stimulus'])

# randomize the order of stimulus for each subject (not doing any form of counter balancing)
for i in range(N_SUBS):
    df_sub = df.sample(len(df)).reset_index(drop=True)

    # save the file out
    sub_fn = os.path.join(orders_dir, f'sub-{str(i).zfill(3)}_{TASK}.json')
    df_sub.to_json(sub_fn, orient='records')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /dartfs/rc/lab/F/FinnLab/tommy/conda/envs/dark_matter/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # How to create a JSPsych experiment
#
# **IGNORE FOR NOW**

# %% [markdown]
# ## (2) Create an experiment tracker
#
# **IGNORE** Not needed immediately!
#
# The tracker serves to log when a participant file has been used, and prevents multiple particpants from using the same file. This tracker file can also be updated in case there is a problem with certain participants' data.

# %% [markdown]
# ## (3) Adding experiment structure to participant level files

# %%
global_parameters = {
    'output_path': "/dartfs/rc/lab/F/FinnLab/tommy/jspsych_experiments/data/",
    'closing_url': CLOSING_URL,
    'num_experiments': 1,
    "current_experiment": 0
}

# experiment_parameters = {
#     "experiment_name": EXPERIMENT_NAME,
#     "experiment_version": p.experiment_version,
#     "task_name": p.task,
#     "experiment_url": os.path.join(URL_BASE, "experiments/next-word-prediction/next-word-prediction.html")
# }
